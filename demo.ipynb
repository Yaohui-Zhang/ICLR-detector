# %% [markdown]
# ## First step : tokenization of the text you want to detect the usage of LLM

# %%
# import packages
import pandas as pd
from tqdm import tqdm
from multiprocessing import Pool
from Model.helper import tokenize_sent
import concurrent.futures
def apply_in_parallel(series, func):
    with concurrent.futures.ProcessPoolExecutor() as executor:
        # Apply func to each element in the series
        results = list(tqdm(executor.map(func, series), total=len(series)))
    return pd.Series(results)  # Return a Series, not a DataFrame

# %%
# for the convenience of the following steps, the input of detector should be a parquet file
df = pd.read_parquet('data/test/ICLR2023.parquet')
# In our example, the column that contains the review text is 'all_review_text', with each row containing a unique review of a paper
display(df)
# Out:
#          review ID                               summary_of_the_paper  \
# 0       EmaqzywPDa  1. This paper studies the effect of label erro...
# 1      1UlNMuZj0fp  This paper considers an important problem of l...
# 2      7AWRUUgNqYe  This paper studies the effect of label error o...
# 3      JhO4VvJYby9  This paper proposes a type of neural networks ...
# 4       uM31Bm53z8  Summary:\nThis article starts from the perspec...
# ...            ...                                                ...
# 18559   nsvAxuM8gv  The paper (as the title suggests) proposes a s...
# 18560   3qrCHCgufw  This paper proposes a structured pruning strat...
# 18561   sjxQy0-OQ7  The paper proposes a method to "enhance explor...
# 18562  4bJbeJX-G6-  The key idea behind this paper is to use a per...
# 18563   ES3_WiAUUX  This paper proposes to use behavior sharing to...
#
#                                  strength_and_weaknesses  \
# 0      Strength\n\n1. They try to answer two signific...
# 1      Strength:\n- This paper is very well organized...
# 2      Strength:\n+ The research problems are importa...
# 3      This paper is motivated by a neurobiological e...
# 4      (Positive) Although this article is very poor,...
# ...                                                  ...
# 18559  The biggest strength of the paper is the detai...
# 18560  Strengths:\n- The performance gains for the pr...
# 18561  ## Strengths\n* The idea to evaluate the polic...
# 18562  This paper is well written, easy to follow and...
# 18563  I don't see obvious strengths in this paper.\n...
#
#            clarity,_quality,_novelty_and_reproducibility  \
# 0      1. Their theoretical analysis seems to be more...
# 1      The paper is clearly written in general, and a...
# 2      This paper generally is well-written and easy ...
# 3      The paper is clear to read. But its quality is...
# 4      The quality, clarity, and the originality are ...
# ...                                                  ...
# 18559  The manuscript is very clear. The quality of t...
# 18560                   Please see the weaknesses above.
# 18561  The 'Weaknesses' section includes the comments...
# 18562  The paper is well written and clear. The ideas...
# 18563  The clarity of this paper is unsatisfying, a l...
#
#                                    summary_of_the_review  \
# 0      1. The overall quality of the paper is good, a...
# 1      Despite the interesting perspective and a well...
# 2      For me, the motivation and research problems o...
# 3      This is a paper inspired by the lateral inhibi...
# 4      See "Summary Of The Paper." Regarding the writ...
# ...                                                  ...
# 18559  While the authors present their proposed appro...
# 18560                   Please see the weaknesses above.
# 18561  The weaknesses of the paper, especially the mo...
# 18562  Overall I think the paper is interesting and w...
# 18563  Overall, this paper has obvious shortcomings i...
#
#                                          all_review_text     paper_id  \
# 0      1. This paper studies the effect of label erro...  RUzSobdYy0V
# 1      This paper considers an important problem of l...  RUzSobdYy0V
# 2      This paper studies the effect of label error o...  RUzSobdYy0V
# 3      This paper proposes a type of neural networks ...  N3kGYG3ZcTi
# 4      Summary:\nThis article starts from the perspec...  N3kGYG3ZcTi
# ...                                                  ...          ...
# 18559  The paper (as the title suggests) proposes a s...   E9_04otJ62
# 18560  This paper proposes a structured pruning strat...   E9_04otJ62
# 18561  The paper proposes a method to "enhance explor...   KjKZaJ5Gbv
# 18562  The key idea behind this paper is to use a per...   KjKZaJ5Gbv
# 18563  This paper proposes to use behavior sharing to...   KjKZaJ5Gbv
#
#                                                 keywords  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3      [Lateral Inhibition, Convolutional Neural Netw...
# 4      [Lateral Inhibition, Convolutional Neural Netw...
# ...                                                  ...
# 18559  [Winograd convolution, structured pruning, GPU...
# 18560  [Winograd convolution, structured pruning, GPU...
# 18561  [Reinforcement Learning, Multitask Reinforceme...
# 18562  [Reinforcement Learning, Multitask Reinforceme...
# 18563  [Reinforcement Learning, Multitask Reinforceme...
#
#                                       inference_sentence
# 0      [[this, paper, studies, the, effect, of, label...
# 1      [[this, paper, considers, an, important, probl...
# 2      [[this, paper, studies, the, effect, of, label...
# 3      [[this, paper, proposes, a, type, of, neural, ...
# 4      [[summary], [this, article, starts, from, the,...
# ...                                                  ...
# 18559  [[the, paper, as, the, title, suggests, propos...
# 18560  [[this, paper, proposes, a, structured, prunin...
# 18561  [[the, paper, proposes, a, method, to, enhance...
# 18562  [[the, key, idea, behind, this, paper, is, to,...
# 18563  [[this, paper, proposes, to, use, behavior, sh...
#
# [18564 rows x 9 columns]

# %%
# call the above function to tokenize the review text and create a new column 'inference_sentence'
# the time of this step depends on the size of the dataset, parallel processing can be used here
df['inference_sentence'] = apply_in_parallel(df['all_review_text'], tokenize_sent)
# Out:
# 100%|██████████| 18564/18564 [04:49<00:00, 64.07it/s]

# %%
# save the result
df.to_parquet('data/test/ICLR2023.parquet')

# %% [markdown]
# ## Example : check the usage of LLM in ICLR2023 and ICLR2024 reviews

# %%
# import packages
import pandas as pd
from Model.model import MLE

# %%
# initialize the detector model
model=MLE()

# %%
# test the LLM usage on ICLR2023 and ICLR2024 reviews
for i in range(2023, 2025):
    # specify the path to the file containing the data you want to detect, 
    # notice that the file must be in parquet format and contains a column named "inference_sentence"
    # the inference_sentence column should contain the sentences you want to detect, created by the previous step tokenize
    # for ICLR2023 reviews, the estimated usage is 2.6%, and for ICLR2024 reviews, the estimated usage is 14.8%
    # CI indicates the confidence interval of the estimated usage
    model.inference(f"data/test/ICLR{i}.parquet")
# Out:
# Prediction,        CI
#      0.026,     0.002
# Prediction,        CI
#      0.148,     0.002
